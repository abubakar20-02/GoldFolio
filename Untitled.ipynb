# %%
# IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import seaborn as sns
import scipy as sp
import sklearn as sk

# %%
df = pd.read_excel("gold_data.xlsx")
col = df.columns
df = df.iloc[:,1:]

scaler = StandardScaler()
df = scaler.fit_transform(df)
df = pd.DataFrame(df, columns = col[1:])
print(df.head)
# Out:
# <bound method NDFrame.head of       S&P 500 Open  USD Index Starting  Oil open  USD To Euro  USD To INR  \
# 0        -1.132275            0.092396 -1.657642     0.009274   -1.033594
# 1        -1.112008            0.083597 -1.644950    -0.008017   -1.029062
# 2        -1.112838            0.135131 -1.678945     0.048375   -1.030605
# 3        -1.106008            0.104965 -1.726538     0.011933   -1.027712
# 4        -1.101301            0.059715 -1.685744    -0.018257   -1.028387
# ...            ...                 ...       ...          ...         ...
# 3432      1.720068            1.079088 -1.680305     0.966053    1.725388
# 3433      1.639624            1.022526 -1.793621     0.954482    1.836261
# 3434      1.658966            1.146963 -1.600984     1.038270    1.745611
# 3435      1.348200            1.187185 -1.671240     1.096124    1.799133
# 3436      1.251064            1.287739 -1.775491     1.177650    1.767897
#
#       USD To CNY  USD To JPY  US Bond 10 Y  GoldToOil  Copper Open  \
# 0       2.130308    0.324454      1.365977  -0.756309    -2.457113
# 1       2.130308    0.345129      1.332054  -0.781339    -2.435395
# 2       2.130457    0.364273      1.305327  -0.746624    -2.445267
# 3       2.130308    0.331345      1.379340  -0.684099    -2.444609
# 4       2.130159    0.320624      1.357753  -0.718713    -2.407755
# ...          ...         ...           ...        ...          ...
# 3432    0.140681    0.064323     -2.427195   4.873545    -0.435396
# 3433    0.162278   -0.001916     -2.252442   5.367499    -0.492651
# 3434    0.177173    0.148404     -2.197960   4.335322    -0.424866
# 3435    0.183131    0.115399     -2.230854   4.572200    -0.502523
# 3436    0.285904    0.120683     -1.954333   4.813644    -0.549907
#
#       Platinum Open  Silver Open  Gold Open  Gold Close
# 0         -1.135162    -1.613869  -2.004686   -2.012532
# 1         -1.145682    -1.613869  -2.011110   -2.015745
# 2         -1.215714    -1.612593  -2.014321   -2.011996
# 3         -1.204894    -1.611317  -2.012180   -2.010925
# 4         -1.180247    -1.592176  -2.002277   -2.000750
# ...             ...          ...        ...         ...
# 3432      -1.054910    -0.117698   1.428912    1.372309
# 3433      -1.034471    -0.192347   1.363339    1.331073
# 3434      -1.038078    -0.191709   1.323193    1.283678
# 3435      -1.297770    -0.245942   1.270735    1.144172
# 3436      -1.411686    -0.332075   1.104528    0.947095
#
# [3437 rows x 14 columns]>

# %%
# calculate the Z-score for each value in the DataFrame
z_scores = np.abs((df - df.mean()) / df.std())

# remove rows where any value has a Z-score greater than 3
df = df[(z_scores < 3).all(axis=1)]

# %%
Predictors= df.iloc[:,:-1]

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(Predictors)

# %%
Predictions = df.iloc[:,-1]

# %%
df_pca = pd.DataFrame(data = principal_components, columns = ['PC1', 'PC2'])
df_pca['target'] = Predictions

# %%
# Create a scatter plot of the first two principal components
# Create figure and axis objects
fig, ax = plt.subplots()
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')

# Plot horizontal line at y=0
ax.axhline(y=0, color='grey', linestyle='--')

# Plot vertical line at x=0
ax.axvline(x=0, color='grey', linestyle='--')

plt.show()

# %%
Predictors.plot(kind='box', subplots=True, layout=(8,4), sharex=False,
sharey=False, fontsize=12, figsize=(15,20))
# Out:
# S&P 500 Open             AxesSubplot(0.125,0.798085;0.168478x0.0819149)
# USD Index Starting    AxesSubplot(0.327174,0.798085;0.168478x0.0819149)
# Oil open              AxesSubplot(0.529348,0.798085;0.168478x0.0819149)
# USD To Euro           AxesSubplot(0.731522,0.798085;0.168478x0.0819149)
# USD To INR               AxesSubplot(0.125,0.699787;0.168478x0.0819149)
# USD To CNY            AxesSubplot(0.327174,0.699787;0.168478x0.0819149)
# USD To JPY            AxesSubplot(0.529348,0.699787;0.168478x0.0819149)
# US Bond 10 Y          AxesSubplot(0.731522,0.699787;0.168478x0.0819149)
# GoldToOil                AxesSubplot(0.125,0.601489;0.168478x0.0819149)
# Copper Open           AxesSubplot(0.327174,0.601489;0.168478x0.0819149)
# Platinum Open         AxesSubplot(0.529348,0.601489;0.168478x0.0819149)
# Silver Open           AxesSubplot(0.731522,0.601489;0.168478x0.0819149)
# Gold Open                AxesSubplot(0.125,0.503191;0.168478x0.0819149)
# dtype: object

# %%
Predictions.plot(kind='box', subplots=True, sharex=False,
sharey=False, fontsize=12, figsize=(15,20))
# Out:
# Gold Close    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
corr = Predictors.corrwith(Predictions)
print(type(corr))
print(corr)
# Out:
# <class 'pandas.core.series.Series'>
# S&P 500 Open          0.371419
# USD Index Starting   -0.027347
# Oil open              0.435324
# USD To Euro           0.059343
# USD To INR            0.481895
# USD To CNY           -0.854894
# USD To JPY           -0.509029
# US Bond 10 Y         -0.827442
# GoldToOil             0.567293
# Copper Open           0.641843
# Platinum Open         0.432937
# Silver Open           0.838906
# Gold Open             0.999568
# dtype: float64

# %%
corr.plot.bar()
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Correlation between Predictors and Predictions')
plt.xlabel('Variable')
plt.ylabel('Correlation')
plt.show()
